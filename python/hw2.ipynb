# %% [markdown]
# 1. Что такое классы и объекты в объектно-ориентированном программировании в Python?
# 2. Как создать классы и инициализировать объекты в Python?
# 3. Какие модификаторы доступа используются для обеспечения инкапсуляции данных и методов класса?
# 4. Что такое наследование и как его применить в Python?
# 5. Какие формы полиморфизма поддерживаются в Python и как их использовать?
# 6. Что такое абстрактные классы и методы, и как их определить в Python?
# 7. Как использовать композицию объектов для создания сложных объектов в Python?
# 8. Какие особенности предоставляет статические методы и свойства классов в Python?
# 9. Что такое декораторы, слоты, метаклассы и как их использовать в Python?
# 10. Какие принципы SOLID применяются в объектно-ориентированном программировании, и как они применяются в Python?
# 11. Какие архитектурные паттерны можно использовать при проектировании классов в Python?
# 12. Как тестировать классы и методы в Python и как находить и исправлять ошибки в коде?
# 13. Как проектировать эффективные классы и методы в Python и обеспечивать оптимизацию работы программы?
